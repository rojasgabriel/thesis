# %% [markdown]
# ## PSTH viewer
#
# Select a unit, event type, and plot type with the controls below.

# %%
from thesis.ephys.tools.psth_viewer import PSTHViewer, PSTHWidget

# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
subject = "GRB058"
session = "20260312_134952"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=5,
)

PSTHWidget(viewer).show()
# Out:
# VBox(children=(HBox(children=(SelectionSlider(continuous_update=False, description='Unit ID:', layout=Layout(m…
