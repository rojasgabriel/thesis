# %% [markdown]
# # General event-aligned PSTH viewer
#
# Select a unit, event type, and plot type with the controls below.

# %%
# %matplotlib widget

from thesis.ephys.utils.viz import PSTHViewer, PSTHWidget

# %%
subject = "GRB058"
session = "20260312_134952"

viewer = PSTHViewer(
    subject=subject,
    session=session,
    unit_criteria_id=1,
    pre_seconds=0.1,
    post_seconds=0.15,
    binwidth_ms=10,
    plot_type="psth",
)
PSTHWidget(viewer).show()
